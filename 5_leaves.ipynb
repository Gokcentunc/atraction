# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokcentunc/atraction/blob/main/5_leaves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4-states topology

# %%
import sympy as sp
from functools import lru_cache
from itertools import product
from collections import defaultdict

# ============================================================
# SETTINGS
# ============================================================

K = 4
NLEAVES = 5
LIGHT_SIMPLIFY = True

PRINT_ALL_CLASSES = True
MAX_CLASSES_TO_SHOW = None   # used only if PRINT_ALL_CLASSES = False

# ============================================================
# SYMBOLS
# ============================================================

pi = sp.symbols("pi1 pi2 pi3 pi4", nonzero=True)
PI_SUM = sum(pi)

pi4 = pi[3]
pi4_elim = {pi4: 1 - (pi[0] + pi[1] + pi[2])}

# ============================================================
# HELPERS
# ============================================================

def idx_to_str(idx):
    return ''.join(str(x) for x in idx)

def pisum(m):
    return sum(pi[:m])

def largest_occurs_once(idx):
    m = max(idx)
    return idx.count(m) == 1

def simp(expr):
    if expr is sp.nan:
        return sp.nan

    expr = sp.expand(expr)
    expr = expr.subs(pi4_elim)
    expr = expr.subs({PI_SUM: 1})
    expr = sp.together(expr)
    expr = sp.cancel(expr)
    expr = sp.factor(expr)
    return expr

def canonical(expr):
    e = simp(expr)
    e = sp.expand(e)
    e = sp.together(e)
    e = sp.cancel(e)
    return sp.srepr(e)

# ============================================================
# CORE FUNCTIONS
# ============================================================

@lru_cache(None)
def e_u(j, i):
    if i == 1:
        return 1
    if j + i <= K + 1:
        return 1
    if j == K + 2 - i:
        return -pisum(K + 1 - i) / pi[(K + 2 - i) - 1]
    return 0

@lru_cache(None)
def norm_u(i):
    if i == 1:
        return 1

    a = K + 1 - i
    b = K + 2 - i
    denom = pi[(K + 2 - i) - 1]

    return simp(pisum(a) * pisum(b) / denom)

@lru_cache(None)
def p0_bar(idx):
    denom = 1
    for ir in idx:
        denom *= norm_u(ir)

    s = 0
    for t in range(1, K + 1):
        prod = 1
        for ir in idx:
            prod *= e_u(t, ir)
        s += pi[t - 1] * prod

    return simp(s / denom)

def make_lam_vec(label):
    lam1 = sp.Symbol(f"lambda_1^{label}")
    lam = sp.Symbol(f"lambda^{label}")
    return [lam1] + [lam] * (K - 1)

# internal edges for q
lam6 = make_lam_vec("6")
lam7 = make_lam_vec("7")

# pendant leaf edges for p
lam1_leaf = make_lam_vec("1")
lam2_leaf = make_lam_vec("2")
lam3_leaf = make_lam_vec("3")
lam4_leaf = make_lam_vec("4")
lam5_leaf = make_lam_vec("5")

# ============================================================
# TOPOLOGY 12|3|45
# First compute \tilde q
# ============================================================

@lru_cache(None)
def barq4(idx4):
    i1, i2, i3, i4 = idx4
    s = 0

    for y in range(1, K + 1):
        s += norm_u(y) * lam6[y - 1] * p0_bar((i1, i2, y)) * p0_bar((y, i3, i4))

    return simp(s)

@lru_cache(None)
def tildeq4(idx4):
    den = p0_bar(idx4)
    if den == 0:
        return sp.nan
    return simp(barq4(idx4) / den)

@lru_cache(None)
def barq5(idx5):
    # topology 12|3|45
    i1, i2, i3, i4, i5 = idx5
    s = 0

    for x in range(1, K + 1):
        s += norm_u(x) * lam7[x - 1] * barq4((i1, i2, i3, x)) * p0_bar((x, i4, i5))

    return simp(s)

@lru_cache(None)
def tildeq5(idx5):
    den = p0_bar(idx5)
    if den == 0:
        return sp.nan
    return simp(barq5(idx5) / den)

# ============================================================
# \tilde p from \tilde q
# \tilde p_{i1...i5} =
# lambda^1_{i1} lambda^2_{i2} lambda^3_{i3} lambda^4_{i4} lambda^5_{i5}
# * \tilde q_{i1...i5}
# ============================================================

@lru_cache(None)
def leaf_factor(idx):
    i1, i2, i3, i4, i5 = idx
    return simp(
        lam1_leaf[i1 - 1] *
        lam2_leaf[i2 - 1] *
        lam3_leaf[i3 - 1] *
        lam4_leaf[i4 - 1] *
        lam5_leaf[i5 - 1]
    )

@lru_cache(None)
def tildep5(idx5):
    qval = tildeq5(idx5)
    if qval is sp.nan:
        return sp.nan
    return simp(leaf_factor(idx5) * qval)

# ============================================================
# MAIN
# ============================================================

def main():
    all_idx = list(product(range(1, K + 1), repeat=NLEAVES))

    zero_indices = []
    nan_indices = []
    expr_classes = defaultdict(list)

    print("Computing \\tilde{p} expressions for topology 12|3|45 ...")

    for idx in all_idx:
        # zero rule
        if largest_occurs_once(idx):
            zero_indices.append(idx)
            continue

        val = tildep5(idx)

        if val is sp.nan:
            nan_indices.append(idx)
            continue

        val = simp(val)

        if val == 0:
            zero_indices.append(idx)
            continue

        key = canonical(val)
        expr_classes[key].append(idx)

    classes = [sorted(v, key=idx_to_str) for v in expr_classes.values() if len(v) >= 2]

    zero_eq_total = len(zero_indices)
    nonzero_eq_total = sum(len(v) - 1 for v in classes)
    total_eq = zero_eq_total + nonzero_eq_total

    print("\n==============================")
    print("EQUALITIES FOR \\tilde{p} ON TOPOLOGY 12|3|45")
    print("==============================")
    print("Number of zero equations      :", zero_eq_total)
    print("Number of equality classes    :", len(classes))
    print("Number of nonzero equations   :", nonzero_eq_total)
    print("Total number of equations     :", total_eq)
    print("Number of NaN indices         :", len(nan_indices))

    print("\n==============================")
    print("ZERO EQUATIONS")
    print("==============================")
    print("Representative rule:")
    print("~p_{i1i2i3i4i5} = 0 whenever the largest index among")
    print("(i1,i2,i3,i4,i5) appears exactly once.")
    if zero_indices:
        print("Example representative:", f"~p_{{{idx_to_str(zero_indices[0])}}}=0")

    classes = sorted(classes, key=lambda x: (-len(x), idx_to_str(x[0])))

    if PRINT_ALL_CLASSES:
        limit = len(classes)
    else:
        limit = MAX_CLASSES_TO_SHOW if MAX_CLASSES_TO_SHOW is not None else len(classes)

    print("\n==============================")
    print("NONZERO EQUALITY CLASSES FOR \\tilde{p}")
    print("==============================")
    print("Total number of nonzero equations :", nonzero_eq_total)

    shown = 0
    for members in classes:
        shown += 1
        eq = " = ".join([f"~p_{{{idx_to_str(x)}}}" for x in members])

        print("\nClass", shown)
        print("size      :", len(members))
        print("equations :", len(members) - 1)
        print(eq)

        if shown >= limit:
            break

if __name__ == "__main__":
    main()
# Out:
# Computing \tilde{p} expressions for topology 12|3|45 ...
#
# ...
# EQUALITIES FOR \tilde{p} ON TOPOLOGY 12|3|45
# ...
# Number of zero equations      : 490
# Number of equality classes    : 48
# Number of nonzero equations   : 464
# Total number of equations     : 954
# Number of NaN indices         : 0
#
# ...
# ZERO EQUATIONS
# ...
# Representative rule:
# ~p_{i1i2i3i4i5} = 0 whenever the largest index among
# (i1,i2,i3,i4,i5) appears exactly once.
# Example representative: ~p_{11112}=0
#
# ...
# NONZERO EQUALITY CLASSES FOR \tilde{p}
# ...
# Total number of nonzero equations : 464
#
# Class 1
# size      : 100
# equations : 99
# ...

# %% [markdown]
# # 4-states model

# %%
import sympy as sp
from functools import lru_cache
from itertools import product, combinations
from collections import defaultdict

# ============================================================
# SETTINGS
# ============================================================

K = 4
NLEAVES = 5
LIGHT_SIMPLIFY = True

PRINT_ALL_CLASSES = True
MAX_CLASSES_TO_SHOW = None   # used only if PRINT_ALL_CLASSES = False

# ============================================================
# SYMBOLS
# ============================================================

pi = sp.symbols("pi1 pi2 pi3 pi4", nonzero=True)
PI_SUM = sum(pi)

pi4 = pi[3]
pi4_elim = {pi4: 1 - (pi[0] + pi[1] + pi[2])}

# ============================================================
# HELPERS
# ============================================================

def idx_to_str(idx):
    return ''.join(str(x) for x in idx)

def pisum(m):
    return sum(pi[:m])

def largest_occurs_once(idx):
    m = max(idx)
    return idx.count(m) == 1

def simp(expr):
    if expr is sp.nan:
        return sp.nan

    expr = sp.expand(expr)
    expr = expr.subs(pi4_elim)
    expr = expr.subs({PI_SUM: 1})
    expr = sp.together(expr)
    expr = sp.cancel(expr)
    expr = sp.factor(expr)
    return expr

def canonical(expr):
    e = simp(expr)
    e = sp.expand(e)
    e = sp.together(e)
    e = sp.cancel(e)
    return sp.srepr(e)

# ============================================================
# CORE FUNCTIONS
# ============================================================

@lru_cache(None)
def e_u(j, i):
    if i == 1:
        return 1
    if j + i <= K + 1:
        return 1
    if j == K + 2 - i:
        return -pisum(K + 1 - i) / pi[(K + 2 - i) - 1]
    return 0

@lru_cache(None)
def norm_u(i):
    if i == 1:
        return 1

    a = K + 1 - i
    b = K + 2 - i
    denom = pi[(K + 2 - i) - 1]

    return simp(pisum(a) * pisum(b) / denom)

@lru_cache(None)
def p0_bar(idx):
    denom = 1
    for ir in idx:
        denom *= norm_u(ir)

    s = 0
    for t in range(1, K + 1):
        prod = 1
        for ir in idx:
            prod *= e_u(t, ir)
        s += pi[t - 1] * prod

    return simp(s / denom)

def make_lam_vec(label):
    lam1 = sp.Symbol(f"lambda_1^{label}")
    lam = sp.Symbol(f"lambda^{label}")
    return [lam1] + [lam] * (K - 1)

# internal edges for q
lam6 = make_lam_vec("6")
lam7 = make_lam_vec("7")

# pendant leaf edges for p
lam1_leaf = make_lam_vec("1")
lam2_leaf = make_lam_vec("2")
lam3_leaf = make_lam_vec("3")
lam4_leaf = make_lam_vec("4")
lam5_leaf = make_lam_vec("5")

# ============================================================
# LOCAL TREE COMPUTATIONS
# Base local topology: 12|3|45
# These compute \tilde q
# ============================================================

@lru_cache(None)
def barq4_local(idx4):
    i1, i2, i3, i4 = idx4
    s = 0

    for y in range(1, K + 1):
        s += norm_u(y) * lam6[y - 1] * p0_bar((i1, i2, y)) * p0_bar((y, i3, i4))

    return simp(s)

@lru_cache(None)
def tildeq4_local(idx4):
    den = p0_bar(idx4)
    if den == 0:
        return sp.nan
    return simp(barq4_local(idx4) / den)

@lru_cache(None)
def barq5_local(idx5):
    # local topology 12|3|45
    i1, i2, i3, i4, i5 = idx5
    s = 0

    for x in range(1, K + 1):
        s += norm_u(x) * lam7[x - 1] * barq4_local((i1, i2, i3, x)) * p0_bar((x, i4, i5))

    return simp(s)

@lru_cache(None)
def tildeq5_local(idx5):
    den = p0_bar(idx5)
    if den == 0:
        return sp.nan
    return simp(barq5_local(idx5) / den)

# ============================================================
# \tilde p from \tilde q
# ============================================================

@lru_cache(None)
def leaf_factor(idx):
    i1, i2, i3, i4, i5 = idx
    return simp(
        lam1_leaf[i1 - 1] *
        lam2_leaf[i2 - 1] *
        lam3_leaf[i3 - 1] *
        lam4_leaf[i4 - 1] *
        lam5_leaf[i5 - 1]
    )

# ============================================================
# ALL 15 TOPOLOGIES
# Each topology is represented as (a,b,c,d,e) meaning ab|c|de
# ============================================================

def all_topologies():
    leaves = [1, 2, 3, 4, 5]
    tops = []

    for pair in combinations(leaves, 2):
        rest = [x for x in leaves if x not in pair]

        for middle in rest:
            other = [x for x in rest if x != middle]
            tops.append((pair[0], pair[1], middle, other[0], other[1]))

    return tops

TOPOLOGIES = all_topologies()

def topology_name(topo):
    a, b, c, d, e = topo
    return f"{a}{b}|{c}|{d}{e}"

def reorder(idx, topo):
    a, b, c, d, e = topo
    return (idx[a - 1], idx[b - 1], idx[c - 1], idx[d - 1], idx[e - 1])

@lru_cache(None)
def tildep5_topology(idx, topo):
    local_idx = reorder(idx, topo)
    qval = tildeq5_local(local_idx)

    if qval is sp.nan:
        return sp.nan

    return simp(leaf_factor(idx) * qval)

# ============================================================
# MAIN
# ============================================================

def main():
    all_idx = list(product(range(1, K + 1), repeat=NLEAVES))

    zero_indices = []
    nan_indices = []
    expr_vectors = defaultdict(list)

    print("Computing \\tilde{p} expressions for all 15 topologies...")

    for idx in all_idx:
        if largest_occurs_once(idx):
            zero_indices.append(idx)
            continue

        vec = []
        has_nan = False
        all_zero = True

        for topo in TOPOLOGIES:
            val = tildep5_topology(idx, topo)

            if val is sp.nan:
                has_nan = True
                break

            val = simp(val)
            if val != 0:
                all_zero = False

            vec.append(canonical(val))

        if has_nan:
            nan_indices.append(idx)
            continue

        if all_zero:
            zero_indices.append(idx)
            continue

        key = tuple(vec)
        expr_vectors[key].append(idx)

    classes = [sorted(v, key=idx_to_str) for v in expr_vectors.values() if len(v) >= 2]

    zero_eq_total = len(zero_indices)
    nonzero_eq_total = sum(len(v) - 1 for v in classes)
    total_eq = zero_eq_total + nonzero_eq_total

    print("\n==============================")
    print("COMMON EQUALITIES FOR \\tilde{p} (ALL 15 TOPOLOGIES)")
    print("==============================")
    print("Number of zero equations      :", zero_eq_total)
    print("Number of equality classes    :", len(classes))
    print("Number of nonzero equations   :", nonzero_eq_total)
    print("Total number of equations     :", total_eq)
    print("Number of NaN indices         :", len(nan_indices))

    print("\nTopologies used:")
    for topo in TOPOLOGIES:
        print("  ", topology_name(topo))

    print("\n==============================")
    print("ZERO EQUATIONS")
    print("==============================")
    print("Representative rule:")
    print("~p_{i1i2i3i4i5} = 0 whenever the largest index among")
    print("(i1,i2,i3,i4,i5) appears exactly once.")
    if zero_indices:
        print("Example representative:", f"~p_{{{idx_to_str(zero_indices[0])}}}=0")

    classes = sorted(classes, key=lambda x: (-len(x), idx_to_str(x[0])))

    if PRINT_ALL_CLASSES:
        limit = len(classes)
    else:
        limit = MAX_CLASSES_TO_SHOW if MAX_CLASSES_TO_SHOW is not None else len(classes)

    print("\n==============================")
    print("NONZERO COMMON EQUALITY CLASSES FOR \\tilde{p}")
    print("==============================")
    print("Total number of nonzero equations :", nonzero_eq_total)

    shown = 0
    for members in classes:
        shown += 1
        eq = " = ".join([f"~p_{{{idx_to_str(x)}}}" for x in members])

        print("\nClass", shown)
        print("size      :", len(members))
        print("equations :", len(members) - 1)
        print(eq)

        if shown >= limit:
            break

if __name__ == "__main__":
    main()
# Out:
# Computing \tilde{p} expressions for all 15 topologies...
#
# ...
# COMMON EQUALITIES FOR \tilde{p} (ALL 15 TOPOLOGIES)
# ...
# Number of zero equations      : 490
# Number of equality classes    : 96
# Number of nonzero equations   : 394
# Total number of equations     : 884
# Number of NaN indices         : 0
#
# Topologies used:
#    12|3|45
#    12|4|35
#    12|5|34
#    13|2|45
#    13|4|25
#    13|5|24
#    14|2|35
#    14|3|25
#    14|5|23
#    15|2|34
#    15|3|24
#    15|4|23
#    23|1|45
#    23|4|15
#    23|5|14
#    24|1|35
#    24|3|15
#    24|5|13
#    25|1|34
#    25|3|14
#    25|4|13
#    34|1|25
#    34|2|15
#    34|5|12
#    35|1|24
#    35|2|14
#    35|4|12
#    45|1|23
#    45|2|13
#    45|3|12
#
# ...
# ZERO EQUATIONS
# ...
# Representative rule:
# ~p_{i1i2i3i4i5} = 0 whenever the largest index among
# (i1,i2,i3,i4,i5) appears exactly once.
# Example representative: ~p_{11112}=0
#
# ...
# NONZERO COMMON EQUALITY CLASSES FOR \tilde{p}
# ...
# Total number of nonzero equations : 394
#
# Class 1
# ...

# %% [markdown]
# # non-binomial

# %%
import sympy as sp
from functools import lru_cache
from itertools import product, combinations

# ============================================================
# SETTINGS
# ============================================================

K = 4
NLEAVES = 5

# ============================================================
# SYMBOLS
# ============================================================

pi = sp.symbols("pi1 pi2 pi3 pi4", nonzero=True)
pi1, pi2, pi3, pi4 = pi
PI_SUM = sum(pi)

pi4_elim = {pi4: 1 - (pi1 + pi2 + pi3)}

# ============================================================
# HELPERS
# ============================================================

def idx_to_str(idx):
    return ''.join(str(x) for x in idx)

def parse_idx(s):
    s = s.strip().replace(" ", "")
    if len(s) != NLEAVES or any(ch not in "1234" for ch in s):
        raise ValueError(f"Index must be a {NLEAVES}-digit string using only 1,2,3,4.")
    return tuple(int(ch) for ch in s)

def parse_idx_list(s):
    s = s.strip()
    if not s:
        return []
    parts = [x.strip() for x in s.split(",") if x.strip()]
    return [parse_idx(x) for x in parts]

def pisum(m):
    return sum(pi[:m])

def contains_one(idx):
    return 1 in idx

def simp(expr):
    if expr is sp.nan:
        return sp.nan
    expr = sp.expand(expr)
    expr = expr.subs(pi4_elim)
    expr = expr.subs({PI_SUM: 1})
    expr = sp.together(expr)
    expr = sp.cancel(expr)
    expr = sp.factor(expr)
    return expr

def has_lambda(expr, lambda_symbols):
    return any(sym in expr.free_symbols for sym in lambda_symbols)

# ============================================================
# CORE FUNCTIONS
# ============================================================

@lru_cache(None)
def e_u(j, i):
    if i == 1:
        return 1
    if j + i <= K + 1:
        return 1
    if j == K + 2 - i:
        return -pisum(K + 1 - i) / pi[(K + 2 - i) - 1]
    return 0

@lru_cache(None)
def norm_u(i):
    if i == 1:
        return 1
    a = K + 1 - i
    b = K + 2 - i
    denom = pi[(K + 2 - i) - 1]
    return simp(pisum(a) * pisum(b) / denom)

@lru_cache(None)
def p0_bar(idx):
    denom = 1
    for ir in idx:
        denom *= norm_u(ir)

    s = 0
    for t in range(1, K + 1):
        prod = 1
        for ir in idx:
            prod *= e_u(t, ir)
        s += pi[t - 1] * prod

    return simp(s / denom)

# ============================================================
# LAMBDAS
# ============================================================

def make_lam_vec(label):
    lam1 = sp.Symbol(f"lambda_1^{label}")
    lam = sp.Symbol(f"lambda^{label}")
    return [lam1] + [lam] * (K - 1)

lam_vec6 = make_lam_vec("6")
lam_vec7 = make_lam_vec("7")

lam1_leaf = make_lam_vec("1")
lam2_leaf = make_lam_vec("2")
lam3_leaf = make_lam_vec("3")
lam4_leaf = make_lam_vec("4")
lam5_leaf = make_lam_vec("5")

LAMBDA_SYMBOLS = [
    sp.Symbol("lambda_1^1"), sp.Symbol("lambda^1"),
    sp.Symbol("lambda_1^2"), sp.Symbol("lambda^2"),
    sp.Symbol("lambda_1^3"), sp.Symbol("lambda^3"),
    sp.Symbol("lambda_1^4"), sp.Symbol("lambda^4"),
    sp.Symbol("lambda_1^5"), sp.Symbol("lambda^5"),
    sp.Symbol("lambda_1^6"), sp.Symbol("lambda^6"),
    sp.Symbol("lambda_1^7"), sp.Symbol("lambda^7"),
]

# ============================================================
# LOCAL TREE COMPUTATIONS
# ============================================================

@lru_cache(None)
def barq4_local(idx4):
    i1, i2, i3, i4 = idx4
    s = 0
    for y in range(1, K + 1):
        s += norm_u(y) * lam_vec6[y - 1] * p0_bar((i1, i2, y)) * p0_bar((y, i3, i4))
    return simp(s)

@lru_cache(None)
def tildeq4_local(idx4):
    den = p0_bar(idx4)
    if den == 0:
        return sp.nan
    return simp(barq4_local(idx4) / den)

@lru_cache(None)
def barq5_local(idx5):
    i1, i2, i3, i4, i5 = idx5
    s = 0
    for x in range(1, K + 1):
        s += norm_u(x) * lam_vec7[x - 1] * barq4_local((i1, i2, i3, x)) * p0_bar((x, i4, i5))
    return simp(s)

@lru_cache(None)
def tildeq5_local(idx5):
    den = p0_bar(idx5)
    if den == 0:
        return sp.nan
    return simp(barq5_local(idx5) / den)

# ============================================================
# \tilde p
# ============================================================

@lru_cache(None)
def leaf_factor(idx):
    i1, i2, i3, i4, i5 = idx
    return simp(
        lam1_leaf[i1 - 1] *
        lam2_leaf[i2 - 1] *
        lam3_leaf[i3 - 1] *
        lam4_leaf[i4 - 1] *
        lam5_leaf[i5 - 1]
    )

# ============================================================
# ALL 15 TOPOLOGIES
# ============================================================

def all_topologies():
    leaves = [1, 2, 3, 4, 5]
    tops = set()

    for pair1 in combinations(leaves, 2):
        rest = [x for x in leaves if x not in pair1]
        for middle in rest:
            pair2 = tuple(sorted([x for x in rest if x != middle]))
            left = tuple(sorted(pair1))
            right = tuple(sorted(pair2))
            if left > right:
                left, right = right, left
            tops.add((left[0], left[1], middle, right[0], right[1]))

    return sorted(tops)

TOPOLOGIES = all_topologies()

def reorder(idx, topo):
    a, b, c, d, e = topo
    return (idx[a - 1], idx[b - 1], idx[c - 1], idx[d - 1], idx[e - 1])

@lru_cache(None)
def tildep5_topology(idx, topo):
    local_idx = reorder(idx, topo)
    qval = tildeq5_local(local_idx)
    if qval is sp.nan:
        return sp.nan
    return simp(leaf_factor(idx) * qval)

# ============================================================
# COEFFICIENT EXTRACTION
# ============================================================

def lambda_coeff_dict(expr):
    expr = simp(expr)

    try:
        poly = sp.Poly(sp.expand(expr), *LAMBDA_SYMBOLS, domain="EX")
    except Exception:
        return None

    d = {}
    for mon, coeff in poly.terms():
        d[mon] = sp.simplify(coeff)

    return d

def solve_same_coeffs_all_topologies(lhs_vec, rhs_vecs):

    m = len(rhs_vecs)
    coeff_syms = sp.symbols(f'c0:{m}')
    equations = []

    for t in range(len(lhs_vec)):

        lhs_dict = lambda_coeff_dict(lhs_vec[t])
        rhs_dicts = [lambda_coeff_dict(rv[t]) for rv in rhs_vecs]

        if lhs_dict is None or any(rd is None for rd in rhs_dicts):
            return None

        monomials = set(lhs_dict.keys())

        for rd in rhs_dicts:
            monomials |= set(rd.keys())

        for mon in monomials:
            lhs_c = lhs_dict.get(mon, 0)
            rhs_c = sum(coeff_syms[j] * rhs_dicts[j].get(mon, 0) for j in range(m))
            equations.append(sp.Eq(lhs_c, rhs_c))

    sols = sp.solve(equations, coeff_syms, dict=True, simplify=True)

    if not sols:
        return None

    for sol in sols:

        coeffs = [sp.simplify(sol[c]) for c in coeff_syms]

        if any(has_lambda(cc, LAMBDA_SYMBOLS) for cc in coeffs):
            continue

        ok = True

        for t in range(len(lhs_vec)):
            test = sp.simplify(lhs_vec[t] - sum(coeffs[j] * rhs_vecs[j][t] for j in range(m)))

            if test != 0:
                ok = False
                break

        if ok:
            return coeffs

    return None

# ============================================================
# PRECOMPUTE ALL VALUES ONCE
# ============================================================

def build_expr_map():

    print("Computing all ~p values for 15 topologies (only once)...")

    all_idx = list(product(range(1, K + 1), repeat=NLEAVES))

    expr_map = {}

    for idx in all_idx:

        if contains_one(idx):
            continue

        vals = []

        bad = False

        for topo in TOPOLOGIES:

            v = tildep5_topology(idx, topo)

            if v is sp.nan:
                bad = True
                break

            vals.append(simp(v))

        if not bad:
            expr_map[idx_to_str(idx)] = tuple(vals)

    print("Precomputation finished.")
    print("Available indices:", len(expr_map))

    return expr_map

# ============================================================
# INTERACTIVE QUERY LOOP
# ============================================================

def query_loop(expr_map):

    while True:

        print("\n--------------------------------------")
        print("New equation search")
        print("--------------------------------------")

        ans = input("Enter LHS index (or q to quit): ").strip()

        if ans.lower() == "q":
            print("Exiting.")
            break

        try:

            lhs_idx = parse_idx(ans)

            if contains_one(lhs_idx):
                raise ValueError("LHS must not contain 1.")

            lhs_key = idx_to_str(lhs_idx)

            rhs_list = parse_idx_list(
                input("Enter RHS indices (comma-separated, any number ≥2): ")
            )

            if len(rhs_list) < 2:
                raise ValueError("Please enter at least 2 RHS indices.")

            if any(contains_one(x) for x in rhs_list):
                raise ValueError("RHS indices must not contain 1.")

            rhs_keys = [idx_to_str(x) for x in rhs_list]

            lhs_vec = expr_map[lhs_key]

            rhs_vecs = [expr_map[k] for k in rhs_keys]

            coeffs = solve_same_coeffs_all_topologies(lhs_vec, rhs_vecs)

            print("\n==============================")
            print("RESULT")
            print("==============================")

            if coeffs is None:
                print("No lambda-free relation found.")
                continue

            relation = f"~p_{{{lhs_key}}} = "

            terms = []

            for c, k in zip(coeffs, rhs_keys):
                terms.append(f"({sp.simplify(c)}) ~p_{{{k}}}")

            relation += " + ".join(terms)

            print("Common relation on all 15 topologies:\n")
            print(relation)

        except Exception as e:

            print("\nError:", e)

# ============================================================
# MAIN
# ============================================================

def main():

    expr_map = build_expr_map()

    query_loop(expr_map)

if __name__ == "__main__":
    main()
# Out:
# Computing all ~p values for 15 topologies (only once)...
# Precomputation finished.
# Available indices: 158
#
# --------------------------------------
# New equation search
# --------------------------------------
# Enter LHS index (or q to quit): 44444
# Enter RHS indices (comma-separated, any number ≥2): 22222,23444
#
# ...
# RESULT
# ...
# Common relation on all 15 topologies:
#
# ...
