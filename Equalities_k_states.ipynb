# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokcentunc/atraction/blob/main/Equalities_k_states.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp
from functools import lru_cache

# ============================================================
# SETTINGS
# ============================================================
EXCLUDE_STATE_1 = True
LIGHT_SIMPLIFY = True
SHOW_DECOMPOSITION = True   # A*lambda_1^6 + B*lambda_1^7 + C

# ============================================================
# Helpers
# ============================================================
def parse_idx(s: str):
    s = s.strip().replace(" ", "")
    if not s or not all(ch.isdigit() for ch in s):
        raise ValueError("Index must be digits like 2244, 22444, 425544.")
    return tuple(int(ch) for ch in s)

def keep_idx(idx):
    return not (EXCLUDE_STATE_1 and (1 in idx))

# ============================================================
# MAIN
# ============================================================
def main():
    K = int(input("Enter kappa (number of states), e.g. 4: ").strip())
    if K < 2:
        raise ValueError("kappa must be >= 2")

    # π variables used internally (we will eliminate piK)
    pi = sp.symbols(" ".join([f"pi{i}" for i in range(1, K + 1)]), nonzero=True)
    PI_SUM = sum(pi)

    # For pretty printing, we want a symbol piK (e.g., pi4) to appear
    piK_sym = pi[-1]  # Symbol piK
    s_noK = sum(pi[:-1])  # pi1+...+pi_{K-1}

    # --- simplex elimination: piK = 1 - (others)
    piK_elim = {piK_sym: 1 - s_noK}

    # --- reverse map for DISPLAY ONLY (put piK back)
    # After elimination, expressions contain (1 - s_noK) and (s_noK - 1).
    # We convert them back to piK and -piK so denominators become piK^2, etc.
    display_subs = {
        (1 - s_noK): piK_sym,
        (s_noK - 1): -piK_sym,
        (PI_SUM - 1): 0,   # in case it survives symbolically
        (1 - PI_SUM): 0
    }

    def pisum(m):
        return sum(pi[:m])

    def pretty_collect(expr):
        # collect wrt lambda symbols for nicer output
        lam_syms = []
        for e in ["6", "7", "8"]:
            lam_syms.append(sp.Symbol(f"lambda_1^{e}"))
            lam_syms.append(sp.Symbol(f"lambda^{e}"))
        return sp.collect(expr, lam_syms, evaluate=True)

    def simp_light(expr):
        if not LIGHT_SIMPLIFY:
            return expr
        # eliminate piK strongly
        expr = expr.subs(piK_elim)
        # also replace PI_SUM if explicitly appears
        expr = expr.subs({PI_SUM: 1})
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = sp.factor(expr)
        expr = pretty_collect(expr)
        return expr

    def pretty_display(expr):
        # bring back piK symbol in the printed expression
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = expr.subs(display_subs)
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = sp.factor(expr)
        expr = pretty_collect(expr)
        return expr

    def decompose_A_B_C(expr, edgeA="6", edgeB="7"):
        """
        Decompose expr as:
            A*lambda_1^edgeA + B*lambda_1^edgeB + C
        assuming it is linear in those symbols.
        """
        lam1A = sp.Symbol(f"lambda_1^{edgeA}")
        lam1B = sp.Symbol(f"lambda_1^{edgeB}")

        # Make it rational-normalized first
        expr0 = sp.together(expr)
        expr0 = sp.cancel(expr0)

        # Use Poly to extract coefficients (works if linear)
        try:
            P = sp.Poly(expr0, lam1A, lam1B, domain="EX")
        except Exception:
            # fallback: brute-force coeffs
            A = sp.diff(expr0, lam1A).subs({lam1A: 0, lam1B: 0})
            B = sp.diff(expr0, lam1B).subs({lam1A: 0, lam1B: 0})
            C = expr0.subs({lam1A: 0, lam1B: 0})
            return sp.simplify(A), sp.simplify(B), sp.simplify(C)

        A = P.coeffs()[0]  # not safe ordering, so do via coeff_monomial
        A = P.coeff_monomial(lam1A)
        B = P.coeff_monomial(lam1B)
        C = P.coeff_monomial(1)

        # if any higher degree terms exist, warn silently by including them into C
        # (you can check with P.total_degree() if you want)
        rest = expr0 - (A*lam1A + B*lam1B + C)
        if rest != 0:
            C = sp.together(C + rest)

        return sp.simplify(A), sp.simplify(B), sp.simplify(C)

    # ============================================================
    # Core cached functions
    # ============================================================
    @lru_cache(maxsize=None)
    def e_u(j, i):
        if i == 1:
            return sp.Integer(1)
        if j + i <= K + 1:
            return sp.Integer(1)
        if j == K + 2 - i:
            return -pisum(K + 1 - i) / pi[(K + 2 - i) - 1]
        return sp.Integer(0)

    @lru_cache(maxsize=None)
    def norm_u(i):
        if i == 1:
            return sp.Integer(1)
        a = K + 1 - i
        b = K + 2 - i
        denom = pi[(K + 2 - i) - 1]
        return simp_light(pisum(a) * pisum(b) / denom)

    @lru_cache(maxsize=None)
    def p0_bar(idx):
        denom = sp.Integer(1)
        for ir in idx:
            denom *= norm_u(ir)

        s = sp.Integer(0)
        for t in range(1, K + 1):
            prod_term = sp.Integer(1)
            for ir in idx:
                prod_term *= e_u(t, ir)
            s += pi[t - 1] * prod_term

        return simp_light(s / denom)

    def make_lam_vec(edge_label: str):
        lam1 = sp.Symbol(f"lambda_1^{edge_label}")
        lam  = sp.Symbol(f"lambda^{edge_label}")
        return [lam1] + [lam] * (K - 1)

    lam_vec6 = make_lam_vec("6")
    lam_vec7 = make_lam_vec("7")
    lam_vec8 = make_lam_vec("8")

    @lru_cache(maxsize=None)
    def barq4(idx4):
        i1, i2, i3, i4 = idx4
        s = sp.Integer(0)
        for y in range(1, K + 1):
            s += norm_u(y) * lam_vec6[y - 1] * p0_bar((i1, i2, y)) * p0_bar((y, i3, i4))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq4(idx4):
        den = p0_bar(idx4)
        return sp.nan if den == 0 else simp_light(barq4(idx4) / den)

    @lru_cache(maxsize=None)
    def barq5(idx5):
        i1, i2, i3, i4, i5 = idx5
        s = sp.Integer(0)
        for x in range(1, K + 1):
            s += norm_u(x) * lam_vec7[x - 1] * barq4((i1, i2, i3, x)) * p0_bar((x, i4, i5))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq5(idx5):
        den = p0_bar(idx5)
        return sp.nan if den == 0 else simp_light(barq5(idx5) / den)

    @lru_cache(maxsize=None)
    def barq6(idx6):
        i1, i2, i3, i4, i5, i6 = idx6
        s = sp.Integer(0)
        for x in range(1, K + 1):
            s += norm_u(x) * lam_vec8[x - 1] * barq5((i1, i2, i3, i4, x)) * p0_bar((x, i5, i6))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq6(idx6):
        den = p0_bar(idx6)
        return sp.nan if den == 0 else simp_light(barq6(idx6) / den)

    def tilde_value(idx, mode):
        if mode == "quartet":
            if len(idx) != 4:
                raise ValueError("quartet requires length-4 indices.")
            return tildeq4(idx)
        if mode == "5":
            if len(idx) != 5:
                raise ValueError("5 requires length-5 indices.")
            return tildeq5(idx)
        if mode == "6":
            if len(idx) != 6:
                raise ValueError("6 requires length-6 indices.")
            return tildeq6(idx)
        raise ValueError("Invalid mode.")

    # ============================================================
    # INPUT / RUN
    # ============================================================
    mode = input("Choose object (quartet / 5 / 6): ").strip().lower()
    if mode not in ["quartet", "5", "6"]:
        raise ValueError("Mode must be one of: quartet, 5, 6.")

    s1 = input("Enter index #1: ").strip()
    s2 = input("Enter index #2: ").strip()

    idx1 = parse_idx(s1)
    idx2 = parse_idx(s2)

    if not keep_idx(idx1) or not keep_idx(idx2):
        raise ValueError("Index rejected: contains state 1 while EXCLUDE_STATE_1=True.")

    v1 = tilde_value(idx1, mode)
    v2 = tilde_value(idx2, mode)

    diff = simp_light(v1 - v2)

    # Display-pretty versions (with piK back)
    v1_disp = pretty_display(v1)
    v2_disp = pretty_display(v2)
    diff_disp = pretty_display(diff)

    print("\n--- Results (pretty: shows piK, i.e. pi4 when K=4) ---")
    print(f"\ntilde({s1}) =")
    print(v1_disp)

    if SHOW_DECOMPOSITION:
        A1, B1, C1 = decompose_A_B_C(v1_disp, edgeA="6", edgeB="7")
        A1, B1, C1 = pretty_display(A1), pretty_display(B1), pretty_display(C1)
        print("\nDecomposition:")
        print(f"A = {A1}")
        print(f"B = {B1}")
        print(f"C = {C1}")
        print(f"Check: A*lambda_1^6 + B*lambda_1^7 + C equals tilde({s1}) ->",
              sp.simplify(v1_disp - (A1*sp.Symbol('lambda_1^6') + B1*sp.Symbol('lambda_1^7') + C1)) == 0)

    print(f"\ntilde({s2}) =")
    print(v2_disp)

    if SHOW_DECOMPOSITION:
        A2, B2, C2 = decompose_A_B_C(v2_disp, edgeA="6", edgeB="7")
        A2, B2, C2 = pretty_display(A2), pretty_display(B2), pretty_display(C2)
        print("\nDecomposition:")
        print(f"A = {A2}")
        print(f"B = {B2}")
        print(f"C = {C2}")
        print(f"Check: A*lambda_1^6 + B*lambda_1^7 + C equals tilde({s2}) ->",
              sp.simplify(v2_disp - (A2*sp.Symbol('lambda_1^6') + B2*sp.Symbol('lambda_1^7') + C2)) == 0)

    print("\n--- Equality check ---")
    print("Naive after simplex simplification ->", diff == 0)

    if diff != 0:
        print("\nDifference (pretty):")
        print(diff_disp)

if __name__ == "__main__":
    main()
# Out:
# Enter kappa (number of states), e.g. 4: 4
# Choose object (quartet / 5 / 6): 5
# Enter index #1: 44244
# Enter index #2: 44344
#
# --- Results (pretty: shows piK, i.e. pi4 when K=4) ---
#
# tilde(44244) =
# -(lambda^6*(2*lambda^7*pi1**2*pi2 - lambda^7*pi1**2 + 2*lambda^7*pi1*pi2**2 + lambda^7*pi1*pi2 - lambda^7*pi2**2 - lambda_1^7*pi1**2*pi2 - lambda_1^7*pi1*pi2**2) + lambda_1^6*(-lambda^7*pi1**2*pi2 - lambda^7*pi1*pi2**2))/(pi1**2 - pi1*pi2 + pi2**2)
#
# Decomposition:
# A = lambda^7*pi1*pi2*(pi1 + pi2)/(pi1**2 - pi1*pi2 + pi2**2)
# B = lambda^6*pi1*pi2*(pi1 + pi2)/(pi1**2 - pi1*pi2 + pi2**2)
# C = -lambda^6*lambda^7*(2*pi1**2*pi2 - pi1**2 + 2*pi1*pi2**2 + pi1*pi2 - pi2**2)/(pi1**2 - pi1*pi2 + pi2**2)
# Check: A*lambda_1^6 + B*lambda_1^7 + C equals tilde(44244) -> True
#
# tilde(44344) =
# -(lambda^6*(2*lambda^7*pi1**2*pi2 - lambda^7*pi1**2 + 2*lambda^7*pi1*pi2**2 + lambda^7*pi1*pi2 - lambda^7*pi2**2 - lambda_1^7*pi1**2*pi2 - lambda_1^7*pi1*pi2**2) + lambda_1^6*(-lambda^7*pi1**2*pi2 - lambda^7*pi1*pi2**2))/(pi1**2 - pi1*pi2 + pi2**2)
#
# Decomposition:
# A = lambda^7*pi1*pi2*(pi1 + pi2)/(pi1**2 - pi1*pi2 + pi2**2)
# B = lambda^6*pi1*pi2*(pi1 + pi2)/(pi1**2 - pi1*pi2 + pi2**2)
# C = -lambda^6*lambda^7*(2*pi1**2*pi2 - pi1**2 + 2*pi1*pi2**2 + pi1*pi2 - pi2**2)/(pi1**2 - pi1*pi2 + pi2**2)
# Check: A*lambda_1^6 + B*lambda_1^7 + C equals tilde(44344) -> True
#
# --- Equality check ---
# Naive after simplex simplification -> True
