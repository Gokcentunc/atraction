# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokcentunc/atraction/blob/main/Equalities_k_states.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp
from functools import lru_cache

# ============================================================
# SETTINGS
# ============================================================
EXCLUDE_STATE_1 = True
LIGHT_SIMPLIFY = True
SHOW_DECOMPOSITION = True  # show linear decomposition in lambda_1^e symbols

# ============================================================
# Helpers
# ============================================================
def parse_idx(s: str):
    s = s.strip().replace(" ", "")
    if not s or not all(ch.isdigit() for ch in s):
        raise ValueError("Index must be digits like 2244, 22444, 425544.")
    return tuple(int(ch) for ch in s)

def keep_idx(idx):
    return not (EXCLUDE_STATE_1 and (1 in idx))

# ============================================================
# MAIN
# ============================================================
def main():
    K = int(input("Enter kappa (number of states), e.g. 4: ").strip())
    if K < 2:
        raise ValueError("kappa must be >= 2")

    # π variables used internally (we will eliminate piK)
    pi = sp.symbols(" ".join([f"pi{i}" for i in range(1, K + 1)]), nonzero=True)
    PI_SUM = sum(pi)

    # For pretty printing, we want a symbol piK (e.g., pi4) to appear
    piK_sym = pi[-1]          # Symbol piK
    s_noK   = sum(pi[:-1])    # pi1+...+pi_{K-1}

    # --- simplex elimination: piK = 1 - (others)
    piK_elim = {piK_sym: 1 - s_noK}

    # --- reverse map for DISPLAY ONLY (put piK back)
    display_subs = {
        (1 - s_noK): piK_sym,
        (s_noK - 1): -piK_sym,
        (PI_SUM - 1): 0,
        (1 - PI_SUM): 0
    }

    def pisum(m):
        return sum(pi[:m])

    def pretty_collect(expr):
        # collect wrt lambda symbols for nicer output
        lam_syms = []
        for e in ["6", "7", "8"]:
            lam_syms.append(sp.Symbol(f"lambda_1^{e}"))
            lam_syms.append(sp.Symbol(f"lambda^{e}"))
        return sp.collect(expr, lam_syms, evaluate=True)

    def simp_light(expr):
        if not LIGHT_SIMPLIFY:
            return expr
        expr = expr.subs(piK_elim)
        expr = expr.subs({PI_SUM: 1})
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = sp.factor(expr)
        expr = pretty_collect(expr)
        return expr

    def pretty_display(expr):
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = expr.subs(display_subs)
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = sp.factor(expr)
        expr = pretty_collect(expr)
        return expr

    def decompose_linear(expr, edges):
        """
        Decompose expr as:  sum_{e in edges} Coef[e] * lambda_1^e  +  Const
        assuming linearity in those lambda_1^e symbols.
        Returns: (coef_dict, const_term)
        """
        lam_syms = [sp.Symbol(f"lambda_1^{e}") for e in edges]

        expr0 = sp.together(expr)
        expr0 = sp.cancel(expr0)

        # Try Poly (best)
        try:
            P = sp.Poly(expr0, *lam_syms, domain="EX")
            coef = {e: sp.simplify(P.coeff_monomial(sp.Symbol(f"lambda_1^{e}"))) for e in edges}
            const = sp.simplify(P.coeff_monomial(1))
            rest = sp.simplify(expr0 - (sum(coef[e]*sp.Symbol(f"lambda_1^{e}") for e in edges) + const))
            if rest != 0:
                const = sp.simplify(sp.together(const + rest))
            return coef, const
        except Exception:
            # Fallback: coefficient extraction by substitution
            subs0 = {sp.Symbol(f"lambda_1^{e}"): 0 for e in edges}
            const = sp.simplify(expr0.subs(subs0))
            coef = {}
            for e in edges:
                lam = sp.Symbol(f"lambda_1^{e}")
                # Since linear, coefficient = expr(lam=1, others=0) - expr(all 0)
                subs1 = dict(subs0)
                subs1[lam] = 1
                coef[e] = sp.simplify(expr0.subs(subs1) - const)
            rest = sp.simplify(expr0 - (sum(coef[e]*sp.Symbol(f"lambda_1^{e}") for e in edges) + const))
            if rest != 0:
                const = sp.simplify(sp.together(const + rest))
            return coef, const

    # ============================================================
    # Core cached functions
    # ============================================================
    @lru_cache(maxsize=None)
    def e_u(j, i):
        if i == 1:
            return sp.Integer(1)
        if j + i <= K + 1:
            return sp.Integer(1)
        if j == K + 2 - i:
            return -pisum(K + 1 - i) / pi[(K + 2 - i) - 1]
        return sp.Integer(0)

    @lru_cache(maxsize=None)
    def norm_u(i):
        if i == 1:
            return sp.Integer(1)
        a = K + 1 - i
        b = K + 2 - i
        denom = pi[(K + 2 - i) - 1]
        return simp_light(pisum(a) * pisum(b) / denom)

    @lru_cache(maxsize=None)
    def p0_bar(idx):
        denom = sp.Integer(1)
        for ir in idx:
            denom *= norm_u(ir)

        s = sp.Integer(0)
        for t in range(1, K + 1):
            prod_term = sp.Integer(1)
            for ir in idx:
                prod_term *= e_u(t, ir)
            s += pi[t - 1] * prod_term

        return simp_light(s / denom)

    def make_lam_vec(edge_label: str):
        lam1 = sp.Symbol(f"lambda_1^{edge_label}")
        lam  = sp.Symbol(f"lambda^{edge_label}")
        return [lam1] + [lam] * (K - 1)

    lam_vec6 = make_lam_vec("6")
    lam_vec7 = make_lam_vec("7")
    lam_vec8 = make_lam_vec("8")

    @lru_cache(maxsize=None)
    def barq4(idx4):
        i1, i2, i3, i4 = idx4
        s = sp.Integer(0)
        for y in range(1, K + 1):
            s += norm_u(y) * lam_vec6[y - 1] * p0_bar((i1, i2, y)) * p0_bar((y, i3, i4))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq4(idx4):
        den = p0_bar(idx4)
        return sp.nan if den == 0 else simp_light(barq4(idx4) / den)

    @lru_cache(maxsize=None)
    def barq5(idx5):
        i1, i2, i3, i4, i5 = idx5
        s = sp.Integer(0)
        for x in range(1, K + 1):
            s += norm_u(x) * lam_vec7[x - 1] * barq4((i1, i2, i3, x)) * p0_bar((x, i4, i5))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq5(idx5):
        den = p0_bar(idx5)
        return sp.nan if den == 0 else simp_light(barq5(idx5) / den)

    @lru_cache(maxsize=None)
    def barq6(idx6):
        i1, i2, i3, i4, i5, i6 = idx6
        s = sp.Integer(0)
        for x in range(1, K + 1):
            s += norm_u(x) * lam_vec8[x - 1] * barq5((i1, i2, i3, i4, x)) * p0_bar((x, i5, i6))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq6(idx6):
        den = p0_bar(idx6)
        return sp.nan if den == 0 else simp_light(barq6(idx6) / den)

    def tilde_value(idx, mode):
        if mode == "quartet":
            if len(idx) != 4:
                raise ValueError("quartet requires length-4 indices.")
            return tildeq4(idx)
        if mode == "5":
            if len(idx) != 5:
                raise ValueError("5 requires length-5 indices.")
            return tildeq5(idx)
        if mode == "6":
            if len(idx) != 6:
                raise ValueError("6 requires length-6 indices.")
            return tildeq6(idx)
        raise ValueError("Invalid mode.")

    def edges_for_mode(mode):
        if mode == "quartet":
            return ["6"]
        if mode == "5":
            return ["6", "7"]
        if mode == "6":
            return ["6", "7", "8"]
        raise ValueError("Invalid mode.")

    # ============================================================
    # INPUT / RUN
    # ============================================================
    mode = input("Choose object (quartet / 5 / 6): ").strip().lower()
    if mode not in ["quartet", "5", "6"]:
        raise ValueError("Mode must be one of: quartet, 5, 6.")

    s1 = input("Enter index #1: ").strip()
    s2 = input("Enter index #2: ").strip()

    idx1 = parse_idx(s1)
    idx2 = parse_idx(s2)

    if not keep_idx(idx1) or not keep_idx(idx2):
        raise ValueError("Index rejected: contains state 1 while EXCLUDE_STATE_1=True.")

    v1 = tilde_value(idx1, mode)
    v2 = tilde_value(idx2, mode)
    diff = simp_light(v1 - v2)

    # Display-pretty versions (with piK back)
    v1_disp = pretty_display(v1)
    v2_disp = pretty_display(v2)
    diff_disp = pretty_display(diff)

    print("\n--- Results (pretty: shows piK, i.e. pi4 when K=4) ---")
    print(f"\ntilde({s1}) =")
    print(v1_disp)

    if SHOW_DECOMPOSITION:
        edges = edges_for_mode(mode)
        coef1, const1 = decompose_linear(v1_disp, edges)
        print("\nDecomposition:")
        for e in edges:
            print(f"Coeff of lambda_1^{e} =", pretty_display(coef1[e]))
        print("Const =", pretty_display(const1))

        # check
        recon1 = sum(coef1[e]*sp.Symbol(f"lambda_1^{e}") for e in edges) + const1
        print("Check decomposition ->", sp.simplify(v1_disp - recon1) == 0)

    print(f"\ntilde({s2}) =")
    print(v2_disp)

    if SHOW_DECOMPOSITION:
        edges = edges_for_mode(mode)
        coef2, const2 = decompose_linear(v2_disp, edges)
        print("\nDecomposition:")
        for e in edges:
            print(f"Coeff of lambda_1^{e} =", pretty_display(coef2[e]))
        print("Const =", pretty_display(const2))

        # check
        recon2 = sum(coef2[e]*sp.Symbol(f"lambda_1^{e}") for e in edges) + const2
        print("Check decomposition ->", sp.simplify(v2_disp - recon2) == 0)

    print("\n--- Equality check ---")
    print("Naive after simplex simplification ->", diff == 0)

    if diff != 0:
        print("\nDifference (pretty):")
        print(diff_disp)

if __name__ == "__main__":
    main()
# Out:
# Enter kappa (number of states), e.g. 4: 5
# Choose object (quartet / 5 / 6): 6
# Enter index #1: 552344
# Enter index #2: 443255
#
# --- Results (pretty: shows piK, i.e. pi4 when K=4) ---
#
# tilde(552344) =
# -(lambda^6*(3*lambda^7*lambda^8*pi1**2 + 6*lambda^7*lambda^8*pi1*pi2 + 3*lambda^7*lambda^8*pi1*pi3 + 3*lambda^7*lambda^8*pi2**2 + 3*lambda^7*lambda^8*pi2*pi3 - lambda^7*lambda^8*pi3 - lambda^7*lambda_1^8*pi1**2 - 2*lambda^7*lambda_1^8*pi1*pi2 - lambda^7*lambda_1^8*pi1*pi3 - lambda^7*lambda_1^8*pi2**2 - lambda^7*lambda_1^8*pi2*pi3 - lambda^8*lambda_1^7*pi1**2 - 2*lambda^8*lambda_1^7*pi1*pi2 - lambda^8*lambda_1^7*pi1*pi3 - lambda^8*lambda_1^7*pi2**2 - lambda^8*lambda_1^7*pi2*pi3) + lambda_1^6*(-lambda^7*lambda^8*pi1**2 - 2*lambda^7*lambda^8*pi1*pi2 - lambda^7*lambda^8*pi1*pi3 - lambda^7*lambda^8*pi2**2 - lambda^7*lambda^8*pi2*pi3))/pi3
#
# Decomposition:
# Coeff of lambda_1^6 = lambda^7*lambda^8*(pi1 + pi2)*(pi1 + pi2 + pi3)/pi3
# Coeff of lambda_1^7 = lambda^6*lambda^8*(pi1 + pi2)*(pi1 + pi2 + pi3)/pi3
# Coeff of lambda_1^8 = lambda^6*lambda^7*(pi1 + pi2)*(pi1 + pi2 + pi3)/pi3
# Const = -lambda^6*lambda^7*lambda^8*(3*pi1**2 + 6*pi1*pi2 + 3*pi1*pi3 + 3*pi2**2 + 3*pi2*pi3 - pi3)/pi3
# Check decomposition -> True
#
# tilde(443255) =
# -(lambda^6*(3*lambda^7*lambda^8*pi1**2 + 6*lambda^7*lambda^8*pi1*pi2 + 3*lambda^7*lambda^8*pi1*pi3 + 3*lambda^7*lambda^8*pi2**2 + 3*lambda^7*lambda^8*pi2*pi3 - lambda^7*lambda^8*pi3 - lambda^7*lambda_1^8*pi1**2 - 2*lambda^7*lambda_1^8*pi1*pi2 - lambda^7*lambda_1^8*pi1*pi3 - lambda^7*lambda_1^8*pi2**2 - lambda^7*lambda_1^8*pi2*pi3 - lambda^8*lambda_1^7*pi1**2 - 2*lambda^8*lambda_1^7*pi1*pi2 - lambda^8*lambda_1^7*pi1*pi3 - lambda^8*lambda_1^7*pi2**2 - lambda^8*lambda_1^7*pi2*pi3) + lambda_1^6*(-lambda^7*lambda^8*pi1**2 - 2*lambda^7*lambda^8*pi1*pi2 - lambda^7*lambda^8*pi1*pi3 - lambda^7*lambda^8*pi2**2 - lambda^7*lambda^8*pi2*pi3))/pi3
#
# Decomposition:
# Coeff of lambda_1^6 = lambda^7*lambda^8*(pi1 + pi2)*(pi1 + pi2 + pi3)/pi3
# Coeff of lambda_1^7 = lambda^6*lambda^8*(pi1 + pi2)*(pi1 + pi2 + pi3)/pi3
# Coeff of lambda_1^8 = lambda^6*lambda^7*(pi1 + pi2)*(pi1 + pi2 + pi3)/pi3
# Const = -lambda^6*lambda^7*lambda^8*(3*pi1**2 + 6*pi1*pi2 + 3*pi1*pi3 + 3*pi2**2 + 3*pi2*pi3 - pi3)/pi3
# Check decomposition -> True
#
# --- Equality check ---
# Naive after simplex simplification -> True

# %% [markdown]
# # faster

# %%
import sympy as sp
from functools import lru_cache

# ============================================================
# SETTINGS
# ============================================================
EXCLUDE_STATE_1 = True
LIGHT_SIMPLIFY = True
FULL_DIFFERENCE_CHECK = False

# ============================================================
# Helpers
# ============================================================
def parse_idx(s: str):
    s = s.strip().replace(" ", "")
    if not s or not all(ch.isdigit() for ch in s):
        raise ValueError("Index must be digits like 2244, 22444, 425544.")
    return tuple(int(ch) for ch in s)

def keep_idx(idx):
    return not (EXCLUDE_STATE_1 and (1 in idx))

# ============================================================
# MAIN
# ============================================================
def main():
    K = int(input("Enter kappa (number of states), e.g. 4: ").strip())
    if K < 2:
        raise ValueError("kappa must be >= 2")

    # π variables used internally
    pi = sp.symbols(" ".join([f"pi{i}" for i in range(1, K + 1)]), nonzero=True)
    PI_SUM = sum(pi)

    # simplex elimination: piK = 1 - (others)
    piK_sym = pi[-1]
    s_noK = sum(pi[:-1])
    piK_elim = {piK_sym: 1 - s_noK}

    # reverse map for display only
    display_subs = {
        (1 - s_noK): piK_sym,
        (s_noK - 1): -piK_sym,
        (PI_SUM - 1): 0,
        (1 - PI_SUM): 0
    }

    def pisum(m):
        return sum(pi[:m])

    def pretty_collect(expr):
        lam_syms = []
        for e in ["6", "7", "8"]:
            lam_syms.append(sp.Symbol(f"lambda_1^{e}"))
            lam_syms.append(sp.Symbol(f"lambda^{e}"))
        return sp.collect(expr, lam_syms, evaluate=True)

    def simp_light(expr):
        if not LIGHT_SIMPLIFY:
            return expr
        expr = expr.subs(piK_elim)
        expr = expr.subs({PI_SUM: 1})
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = sp.factor(expr)
        expr = pretty_collect(expr)
        return expr

    def pretty_display(expr):
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = expr.subs(display_subs)
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = sp.factor(expr)
        expr = pretty_collect(expr)
        return expr

    def edges_for_mode(mode):
        if mode == "quartet":
            return ["6"]
        if mode == "5":
            return ["6", "7"]
        if mode == "6":
            return ["6", "7", "8"]
        raise ValueError("Invalid mode.")

    def decompose_linear_fast(expr, edges):
        """
        expr = sum_e coef[e] * lambda_1^e + const
        Assumes linearity in lambda_1^e.
        """
        lam_syms = [sp.Symbol(f"lambda_1^{e}") for e in edges]

        expr0 = sp.together(expr)
        expr0 = sp.cancel(expr0)

        subs0 = {lam: 0 for lam in lam_syms}
        const = sp.simplify(expr0.subs(subs0))

        coef = {}
        for lam, e in zip(lam_syms, edges):
            coef[e] = sp.simplify(expr0.coeff(lam, 1).subs(subs0))

        return coef, const

    def compare_by_parts(v1, v2, mode):
        edges = edges_for_mode(mode)

        coef1, const1 = decompose_linear_fast(v1, edges)
        coef2, const2 = decompose_linear_fast(v2, edges)

        print("\n--- Equality check by coefficients ---")
        all_equal = True

        for e in edges:
            diff_e = simp_light(coef1[e] - coef2[e])
            ok = (diff_e == 0)
            print(f"Coeff of lambda_1^{e} equal? -> {ok}")
            if not ok:
                print(f"Difference in coeff lambda_1^{e} =")
                print(pretty_display(diff_e))
                all_equal = False

        diff_c = simp_light(const1 - const2)
        ok_c = (diff_c == 0)
        print(f"Constant term equal? -> {ok_c}")
        if not ok_c:
            print("Difference in constant term =")
            print(pretty_display(diff_c))
            all_equal = False

        print("\nOverall equal by decomposition? ->", all_equal)
        return all_equal

    # ============================================================
    # Core cached functions
    # ============================================================
    @lru_cache(maxsize=None)
    def e_u(j, i):
        if i == 1:
            return sp.Integer(1)
        if j + i <= K + 1:
            return sp.Integer(1)
        if j == K + 2 - i:
            return -pisum(K + 1 - i) / pi[(K + 2 - i) - 1]
        return sp.Integer(0)

    @lru_cache(maxsize=None)
    def norm_u(i):
        if i == 1:
            return sp.Integer(1)
        a = K + 1 - i
        b = K + 2 - i
        denom = pi[(K + 2 - i) - 1]
        return simp_light(pisum(a) * pisum(b) / denom)

    @lru_cache(maxsize=None)
    def p0_bar(idx):
        denom = sp.Integer(1)
        for ir in idx:
            denom *= norm_u(ir)

        s = sp.Integer(0)
        for t in range(1, K + 1):
            prod_term = sp.Integer(1)
            for ir in idx:
                prod_term *= e_u(t, ir)
            s += pi[t - 1] * prod_term

        return simp_light(s / denom)

    def make_lam_vec(edge_label: str):
        lam1 = sp.Symbol(f"lambda_1^{edge_label}")
        lam  = sp.Symbol(f"lambda^{edge_label}")
        return [lam1] + [lam] * (K - 1)

    lam_vec6 = make_lam_vec("6")
    lam_vec7 = make_lam_vec("7")
    lam_vec8 = make_lam_vec("8")

    @lru_cache(maxsize=None)
    def barq4(idx4):
        i1, i2, i3, i4 = idx4
        s = sp.Integer(0)
        for y in range(1, K + 1):
            s += norm_u(y) * lam_vec6[y - 1] * p0_bar((i1, i2, y)) * p0_bar((y, i3, i4))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq4(idx4):
        den = p0_bar(idx4)
        return sp.nan if den == 0 else simp_light(barq4(idx4) / den)

    @lru_cache(maxsize=None)
    def barq5(idx5):
        i1, i2, i3, i4, i5 = idx5
        s = sp.Integer(0)
        for x in range(1, K + 1):
            s += norm_u(x) * lam_vec7[x - 1] * barq4((i1, i2, i3, x)) * p0_bar((x, i4, i5))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq5(idx5):
        den = p0_bar(idx5)
        return sp.nan if den == 0 else simp_light(barq5(idx5) / den)

    @lru_cache(maxsize=None)
    def barq6(idx6):
        i1, i2, i3, i4, i5, i6 = idx6
        s = sp.Integer(0)
        for x in range(1, K + 1):
            s += norm_u(x) * lam_vec8[x - 1] * barq5((i1, i2, i3, i4, x)) * p0_bar((x, i5, i6))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq6(idx6):
        den = p0_bar(idx6)
        return sp.nan if den == 0 else simp_light(barq6(idx6) / den)

    def tilde_value(idx, mode):
        if mode == "quartet":
            if len(idx) != 4:
                raise ValueError("quartet requires length-4 indices.")
            return tildeq4(idx)
        if mode == "5":
            if len(idx) != 5:
                raise ValueError("5 requires length-5 indices.")
            return tildeq5(idx)
        if mode == "6":
            if len(idx) != 6:
                raise ValueError("6 requires length-6 indices.")
            return tildeq6(idx)
        raise ValueError("Invalid mode.")

    # ============================================================
    # INPUT / RUN
    # ============================================================
    mode = input("Choose object (quartet / 5 / 6): ").strip().lower()
    if mode not in ["quartet", "5", "6"]:
        raise ValueError("Mode must be one of: quartet, 5, 6.")

    s1 = input("Enter index #1: ").strip()
    s2 = input("Enter index #2: ").strip()

    idx1 = parse_idx(s1)
    idx2 = parse_idx(s2)

    if not keep_idx(idx1) or not keep_idx(idx2):
        raise ValueError("Index rejected: contains state 1 while EXCLUDE_STATE_1=True.")

    if mode == "quartet" and (len(idx1) != 4 or len(idx2) != 4):
        raise ValueError("quartet mode requires length-4 indices.")
    if mode == "5" and (len(idx1) != 5 or len(idx2) != 5):
        raise ValueError("5 mode requires length-5 indices.")
    if mode == "6" and (len(idx1) != 6 or len(idx2) != 6):
        raise ValueError("6 mode requires length-6 indices.")

    print("\nComputing first value...")
    v1 = tilde_value(idx1, mode)

    print("Computing second value...")
    v2 = tilde_value(idx2, mode)

    v1_disp = pretty_display(v1)
    v2_disp = pretty_display(v2)

    print("\n--- Results (pretty: shows piK, e.g. pi4 when K=4) ---")
    print(f"\ntilde({s1}) =")
    print(v1_disp)

    print(f"\ntilde({s2}) =")
    print(v2_disp)

    compare_by_parts(v1, v2, mode)

    if FULL_DIFFERENCE_CHECK:
        print("\n--- Full difference check ---")
        diff = simp_light(v1 - v2)
        print("Naive after simplex simplification ->", diff == 0)
        if diff != 0:
            print("\nDifference (pretty):")
            print(pretty_display(diff))

if __name__ == "__main__":
    main()
# Out:
# Enter kappa (number of states), e.g. 4: 8
# Choose object (quartet / 5 / 6): 6
# Enter index #1: 882366
# Enter index #2: 663288
#
# Computing first value...
# Computing second value...
#
# --- Results (pretty: shows piK, e.g. pi4 when K=4) ---
#
# tilde(882366) =
# -(lambda^6*(3*lambda^7*lambda^8*pi1**2 + 6*lambda^7*lambda^8*pi1*pi2 + 6*lambda^7*lambda^8*pi1*pi3 + 3*lambda^7*lambda^8*pi1*pi4 + 3*lambda^7*lambda^8*pi2**2 + 6*lambda^7*lambda^8*pi2*pi3 + 3*lambda^7*lambda^8*pi2*pi4 + 3*lambda^7*lambda^8*pi3**2 + 3*lambda^7*lambda^8*pi3*pi4 - lambda^7*lambda^8*pi4 - lambda^7*lambda_1^8*pi1**2 - 2*lambda^7*lambda_1^8*pi1*pi2 - 2*lambda^7*lambda_1^8*pi1*pi3 - lambda^7*lambda_1^8*pi1*pi4 - lambda^7*lambda_1^8*pi2**2 - 2*lambda^7*lambda_1^8*pi2*pi3 - lambda^7*lambda_1^8*pi2*pi4 - lambda^7*lambda_1^8*pi3**2 - lambda^7*lambda_1^8*pi3*pi4 - lambda^8*lambda_1^7*pi1**2 - 2*lambda^8*lambda_1^7*pi1*pi2 - 2*lambda^8*lambda_1^7*pi1*pi3 - lambda^8*lambda_1^7*pi1*pi4 - lambda^8*lambda_1^7*pi2**2 - 2*lambda^8*lambda_1^7*pi2*pi3 - lambda^8*lambda_1^7*pi2*pi4 - lambda^8*lambda_1^7*pi3**2 - lambda^8*lambda_1^7*pi3*pi4) + lambda_1^6*(-lambda^7*lambda^8*pi1**2 - 2*lambda^7*lambda^8*pi1*pi2 - 2*lambda^7*lambda^8*pi1*pi3 - lambda^7*lambda^8*pi1*pi4 - lambda^7*lambda^8*pi2**2 - 2*lambda^7*lambda^8*pi2*pi3 - lambda^7*lambda^8*pi2*pi4 - lambda^7*lambda^8*pi3**2 - lambda^7*lambda^8*pi3*pi4))/pi4
#
# tilde(663288) =
# -(lambda^6*(3*lambda^7*lambda^8*pi1**2 + 6*lambda^7*lambda^8*pi1*pi2 + 6*lambda^7*lambda^8*pi1*pi3 + 3*lambda^7*lambda^8*pi1*pi4 + 3*lambda^7*lambda^8*pi2**2 + 6*lambda^7*lambda^8*pi2*pi3 + 3*lambda^7*lambda^8*pi2*pi4 + 3*lambda^7*lambda^8*pi3**2 + 3*lambda^7*lambda^8*pi3*pi4 - lambda^7*lambda^8*pi4 - lambda^7*lambda_1^8*pi1**2 - 2*lambda^7*lambda_1^8*pi1*pi2 - 2*lambda^7*lambda_1^8*pi1*pi3 - lambda^7*lambda_1^8*pi1*pi4 - lambda^7*lambda_1^8*pi2**2 - 2*lambda^7*lambda_1^8*pi2*pi3 - lambda^7*lambda_1^8*pi2*pi4 - lambda^7*lambda_1^8*pi3**2 - lambda^7*lambda_1^8*pi3*pi4 - lambda^8*lambda_1^7*pi1**2 - 2*lambda^8*lambda_1^7*pi1*pi2 - 2*lambda^8*lambda_1^7*pi1*pi3 - lambda^8*lambda_1^7*pi1*pi4 - lambda^8*lambda_1^7*pi2**2 - 2*lambda^8*lambda_1^7*pi2*pi3 - lambda^8*lambda_1^7*pi2*pi4 - lambda^8*lambda_1^7*pi3**2 - lambda^8*lambda_1^7*pi3*pi4) + lambda_1^6*(-lambda^7*lambda^8*pi1**2 - 2*lambda^7*lambda^8*pi1*pi2 - 2*lambda^7*lambda^8*pi1*pi3 - lambda^7*lambda^8*pi1*pi4 - lambda^7*lambda^8*pi2**2 - 2*lambda^7*lambda^8*pi2*pi3 - lambda^7*lambda^8*pi2*pi4 - lambda^7*lambda^8*pi3**2 - lambda^7*lambda^8*pi3*pi4))/pi4
#
# --- Equality check by coefficients ---
# Coeff of lambda_1^6 equal? -> True
# Coeff of lambda_1^7 equal? -> True
# Coeff of lambda_1^8 equal? -> True
# Constant term equal? -> True
#
# Overall equal by decomposition? -> True
