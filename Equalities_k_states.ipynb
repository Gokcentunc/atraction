# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokcentunc/atraction/blob/main/Equalities_k_states.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # k-states

# %%
import sympy as sp
from functools import lru_cache

# ============================================================
# SETTINGS
# ============================================================
EXCLUDE_STATE_1 = True
LIGHT_SIMPLIFY = True
SHOW_DECOMPOSITION = True  # show linear decomposition in lambda_1^e symbols

# ============================================================
# Helpers
# ============================================================
def parse_idx(s: str):
    s = s.strip().replace(" ", "")
    if not s or not all(ch.isdigit() for ch in s):
        raise ValueError("Index must be digits like 2244, 22444, 425544.")
    return tuple(int(ch) for ch in s)

def keep_idx(idx):
    return not (EXCLUDE_STATE_1 and (1 in idx))

# ============================================================
# MAIN
# ============================================================
def main():
    K = int(input("Enter kappa (number of states), e.g. 4: ").strip())
    if K < 2:
        raise ValueError("kappa must be >= 2")

    # π variables used internally (we will eliminate piK)
    pi = sp.symbols(" ".join([f"pi{i}" for i in range(1, K + 1)]), nonzero=True)
    PI_SUM = sum(pi)

    # For pretty printing, we want a symbol piK (e.g., pi4) to appear
    piK_sym = pi[-1]          # Symbol piK
    s_noK   = sum(pi[:-1])    # pi1+...+pi_{K-1}

    # --- simplex elimination: piK = 1 - (others)
    piK_elim = {piK_sym: 1 - s_noK}

    # --- reverse map for DISPLAY ONLY (put piK back)
    display_subs = {
        (1 - s_noK): piK_sym,
        (s_noK - 1): -piK_sym,
        (PI_SUM - 1): 0,
        (1 - PI_SUM): 0
    }

    def pisum(m):
        return sum(pi[:m])

    def pretty_collect(expr):
        # collect wrt lambda symbols for nicer output
        lam_syms = []
        for e in ["6", "7", "8"]:
            lam_syms.append(sp.Symbol(f"lambda_1^{e}"))
            lam_syms.append(sp.Symbol(f"lambda^{e}"))
        return sp.collect(expr, lam_syms, evaluate=True)

    def simp_light(expr):
        if not LIGHT_SIMPLIFY:
            return expr
        expr = expr.subs(piK_elim)
        expr = expr.subs({PI_SUM: 1})
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = sp.factor(expr)
        expr = pretty_collect(expr)
        return expr

    def pretty_display(expr):
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = expr.subs(display_subs)
        expr = sp.together(expr)
        expr = sp.cancel(expr)
        expr = sp.factor(expr)
        expr = pretty_collect(expr)
        return expr

    def decompose_linear(expr, edges):
        """
        Decompose expr as:  sum_{e in edges} Coef[e] * lambda_1^e  +  Const
        assuming linearity in those lambda_1^e symbols.
        Returns: (coef_dict, const_term)
        """
        lam_syms = [sp.Symbol(f"lambda_1^{e}") for e in edges]

        expr0 = sp.together(expr)
        expr0 = sp.cancel(expr0)

        # Try Poly (best)
        try:
            P = sp.Poly(expr0, *lam_syms, domain="EX")
            coef = {e: sp.simplify(P.coeff_monomial(sp.Symbol(f"lambda_1^{e}"))) for e in edges}
            const = sp.simplify(P.coeff_monomial(1))
            rest = sp.simplify(expr0 - (sum(coef[e]*sp.Symbol(f"lambda_1^{e}") for e in edges) + const))
            if rest != 0:
                const = sp.simplify(sp.together(const + rest))
            return coef, const
        except Exception:
            # Fallback: coefficient extraction by substitution
            subs0 = {sp.Symbol(f"lambda_1^{e}"): 0 for e in edges}
            const = sp.simplify(expr0.subs(subs0))
            coef = {}
            for e in edges:
                lam = sp.Symbol(f"lambda_1^{e}")
                # Since linear, coefficient = expr(lam=1, others=0) - expr(all 0)
                subs1 = dict(subs0)
                subs1[lam] = 1
                coef[e] = sp.simplify(expr0.subs(subs1) - const)
            rest = sp.simplify(expr0 - (sum(coef[e]*sp.Symbol(f"lambda_1^{e}") for e in edges) + const))
            if rest != 0:
                const = sp.simplify(sp.together(const + rest))
            return coef, const

    # ============================================================
    # Core cached functions
    # ============================================================
    @lru_cache(maxsize=None)
    def e_u(j, i):
        if i == 1:
            return sp.Integer(1)
        if j + i <= K + 1:
            return sp.Integer(1)
        if j == K + 2 - i:
            return -pisum(K + 1 - i) / pi[(K + 2 - i) - 1]
        return sp.Integer(0)

    @lru_cache(maxsize=None)
    def norm_u(i):
        if i == 1:
            return sp.Integer(1)
        a = K + 1 - i
        b = K + 2 - i
        denom = pi[(K + 2 - i) - 1]
        return simp_light(pisum(a) * pisum(b) / denom)

    @lru_cache(maxsize=None)
    def p0_bar(idx):
        denom = sp.Integer(1)
        for ir in idx:
            denom *= norm_u(ir)

        s = sp.Integer(0)
        for t in range(1, K + 1):
            prod_term = sp.Integer(1)
            for ir in idx:
                prod_term *= e_u(t, ir)
            s += pi[t - 1] * prod_term

        return simp_light(s / denom)

    def make_lam_vec(edge_label: str):
        lam1 = sp.Symbol(f"lambda_1^{edge_label}")
        lam  = sp.Symbol(f"lambda^{edge_label}")
        return [lam1] + [lam] * (K - 1)

    lam_vec6 = make_lam_vec("6")
    lam_vec7 = make_lam_vec("7")
    lam_vec8 = make_lam_vec("8")

    @lru_cache(maxsize=None)
    def barq4(idx4):
        i1, i2, i3, i4 = idx4
        s = sp.Integer(0)
        for y in range(1, K + 1):
            s += norm_u(y) * lam_vec6[y - 1] * p0_bar((i1, i2, y)) * p0_bar((y, i3, i4))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq4(idx4):
        den = p0_bar(idx4)
        return sp.nan if den == 0 else simp_light(barq4(idx4) / den)

    @lru_cache(maxsize=None)
    def barq5(idx5):
        i1, i2, i3, i4, i5 = idx5
        s = sp.Integer(0)
        for x in range(1, K + 1):
            s += norm_u(x) * lam_vec7[x - 1] * barq4((i1, i2, i3, x)) * p0_bar((x, i4, i5))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq5(idx5):
        den = p0_bar(idx5)
        return sp.nan if den == 0 else simp_light(barq5(idx5) / den)

    @lru_cache(maxsize=None)
    def barq6(idx6):
        i1, i2, i3, i4, i5, i6 = idx6
        s = sp.Integer(0)
        for x in range(1, K + 1):
            s += norm_u(x) * lam_vec8[x - 1] * barq5((i1, i2, i3, i4, x)) * p0_bar((x, i5, i6))
        return simp_light(s)

    @lru_cache(maxsize=None)
    def tildeq6(idx6):
        den = p0_bar(idx6)
        return sp.nan if den == 0 else simp_light(barq6(idx6) / den)

    def tilde_value(idx, mode):
        if mode == "quartet":
            if len(idx) != 4:
                raise ValueError("quartet requires length-4 indices.")
            return tildeq4(idx)
        if mode == "5":
            if len(idx) != 5:
                raise ValueError("5 requires length-5 indices.")
            return tildeq5(idx)
        if mode == "6":
            if len(idx) != 6:
                raise ValueError("6 requires length-6 indices.")
            return tildeq6(idx)
        raise ValueError("Invalid mode.")

    def edges_for_mode(mode):
        if mode == "quartet":
            return ["6"]
        if mode == "5":
            return ["6", "7"]
        if mode == "6":
            return ["6", "7", "8"]
        raise ValueError("Invalid mode.")

    # ============================================================
    # INPUT / RUN
    # ============================================================
    mode = input("Choose object (quartet / 5 / 6): ").strip().lower()
    if mode not in ["quartet", "5", "6"]:
        raise ValueError("Mode must be one of: quartet, 5, 6.")

    s1 = input("Enter index #1: ").strip()
    s2 = input("Enter index #2: ").strip()

    idx1 = parse_idx(s1)
    idx2 = parse_idx(s2)

    if not keep_idx(idx1) or not keep_idx(idx2):
        raise ValueError("Index rejected: contains state 1 while EXCLUDE_STATE_1=True.")

    v1 = tilde_value(idx1, mode)
    v2 = tilde_value(idx2, mode)
    diff = simp_light(v1 - v2)

    # Display-pretty versions (with piK back)
    v1_disp = pretty_display(v1)
    v2_disp = pretty_display(v2)
    diff_disp = pretty_display(diff)

    print("\n--- Results (pretty: shows piK, i.e. pi4 when K=4) ---")
    print(f"\ntilde({s1}) =")
    print(v1_disp)

    if SHOW_DECOMPOSITION:
        edges = edges_for_mode(mode)
        coef1, const1 = decompose_linear(v1_disp, edges)
        print("\nDecomposition:")
        for e in edges:
            print(f"Coeff of lambda_1^{e} =", pretty_display(coef1[e]))
        print("Const =", pretty_display(const1))

        # check
        recon1 = sum(coef1[e]*sp.Symbol(f"lambda_1^{e}") for e in edges) + const1
        print("Check decomposition ->", sp.simplify(v1_disp - recon1) == 0)

    print(f"\ntilde({s2}) =")
    print(v2_disp)

    if SHOW_DECOMPOSITION:
        edges = edges_for_mode(mode)
        coef2, const2 = decompose_linear(v2_disp, edges)
        print("\nDecomposition:")
        for e in edges:
            print(f"Coeff of lambda_1^{e} =", pretty_display(coef2[e]))
        print("Const =", pretty_display(const2))

        # check
        recon2 = sum(coef2[e]*sp.Symbol(f"lambda_1^{e}") for e in edges) + const2
        print("Check decomposition ->", sp.simplify(v2_disp - recon2) == 0)

    print("\n--- Equality check ---")
    print("Naive after simplex simplification ->", diff == 0)

    if diff != 0:
        print("\nDifference (pretty):")
        print(diff_disp)

if __name__ == "__main__":
    main()
# Out:
# Enter kappa (number of states), e.g. 4: 5
# Choose object (quartet / 5 / 6): 6
# Enter index #1: 552344
# Enter index #2: 443255
#
# --- Results (pretty: shows piK, i.e. pi4 when K=4) ---
#
# tilde(552344) =
# -(lambda^6*(3*lambda^7*lambda^8*pi1**2 + 6*lambda^7*lambda^8*pi1*pi2 + 3*lambda^7*lambda^8*pi1*pi3 + 3*lambda^7*lambda^8*pi2**2 + 3*lambda^7*lambda^8*pi2*pi3 - lambda^7*lambda^8*pi3 - lambda^7*lambda_1^8*pi1**2 - 2*lambda^7*lambda_1^8*pi1*pi2 - lambda^7*lambda_1^8*pi1*pi3 - lambda^7*lambda_1^8*pi2**2 - lambda^7*lambda_1^8*pi2*pi3 - lambda^8*lambda_1^7*pi1**2 - 2*lambda^8*lambda_1^7*pi1*pi2 - lambda^8*lambda_1^7*pi1*pi3 - lambda^8*lambda_1^7*pi2**2 - lambda^8*lambda_1^7*pi2*pi3) + lambda_1^6*(-lambda^7*lambda^8*pi1**2 - 2*lambda^7*lambda^8*pi1*pi2 - lambda^7*lambda^8*pi1*pi3 - lambda^7*lambda^8*pi2**2 - lambda^7*lambda^8*pi2*pi3))/pi3
#
# Decomposition:
# Coeff of lambda_1^6 = lambda^7*lambda^8*(pi1 + pi2)*(pi1 + pi2 + pi3)/pi3
# ...

# %% [markdown]
# # k-states faster

# %%
import sympy as sp
import random

# ============================================================
# SETTINGS
# ============================================================
EXCLUDE_STATE_1 = True
SIMPLIFY_LEVEL = 1
NUM_RANDOM_TESTS = 5   # increase if you want more confidence

# ============================================================
# Helpers
# ============================================================
def parse_idx(s: str):
    s = s.strip().replace(" ", "")
    if not s or not all(ch.isdigit() for ch in s):
        raise ValueError("Index must be digits like 2244, 22444.")
    return tuple(int(ch) for ch in s)

def keep_idx(idx):
    return not (EXCLUDE_STATE_1 and (1 in idx))

def check_idx_range(idx, K):
    bad = [d for d in idx if not (1 <= d <= K)]
    if bad:
        raise ValueError(f"Index {idx} contains digits outside 1..{K}: {bad}")

def simp_pi(expr, piK_elim, PI_SUM):
    expr = expr.subs(piK_elim).subs({PI_SUM: 1})
    if SIMPLIFY_LEVEL >= 1:
        expr = sp.together(expr)
        expr = sp.cancel(expr)
    if SIMPLIFY_LEVEL >= 2:
        expr = sp.factor(expr)
    return expr

# ============================================================
# MAIN
# ============================================================
def main():

    K = int(input("Enter kappa (number of states), e.g. 8: ").strip())
    mode = input("Choose object (quartet / 5 / 6): ").strip().lower()

    s1 = input("Enter index #1: ").strip()
    s2 = input("Enter index #2: ").strip()

    idx1 = parse_idx(s1)
    idx2 = parse_idx(s2)

    need_len = {"quartet":4,"5":5,"6":6}[mode]

    if len(idx1)!=need_len or len(idx2)!=need_len:
        raise ValueError(f"{mode} requires length {need_len}")

    check_idx_range(idx1,K)
    check_idx_range(idx2,K)

    if not keep_idx(idx1) or not keep_idx(idx2):
        raise ValueError("Index rejected: contains state 1")

    # --------------------------------------------------------
    # pi variables
    # --------------------------------------------------------
    pi = sp.symbols(" ".join([f"pi{i}" for i in range(1,K+1)]), nonzero=True)
    PI_SUM = sum(pi)

    piK_sym = pi[-1]
    s_noK = sum(pi[:-1])

    piK_elim = {piK_sym:1-s_noK}

    # --------------------------------------------------------
    # prefix sums
    # --------------------------------------------------------
    ps=[sp.Integer(0)]
    run=sp.Integer(0)

    for i in range(K):
        run+=pi[i]
        ps.append(run)

    def pisum(m):
        return ps[m]

    # --------------------------------------------------------
    # e_u and norm_u
    # --------------------------------------------------------
    e_u=[[sp.Integer(0)]*(K+1) for _ in range(K+1)]
    norm_u=[sp.Integer(0)]*(K+1)

    for j in range(1,K+1):

        for i in range(1,K+1):

            if i==1:
                e_u[j][i]=1

            elif j+i<=K+1:
                e_u[j][i]=1

            elif j==K+2-i:
                e_u[j][i] = -pisum(K+1-i)/pi[(K+2-i)-1]

            else:
                e_u[j][i]=0

    norm_u[1]=1

    for i in range(2,K+1):

        a=K+1-i
        b=K+2-i
        denom=pi[(K+2-i)-1]

        norm_u[i]=pisum(a)*pisum(b)/denom

    # --------------------------------------------------------
    # p0 cache
    # --------------------------------------------------------
    p0_cache={}

    def p0_bar(idx):

        if idx in p0_cache:
            return p0_cache[idx]

        denom=sp.Integer(1)

        for ir in idx:
            denom*=norm_u[ir]

        s=sp.Integer(0)

        for t in range(1,K+1):

            prod_term=sp.Integer(1)

            for ir in idx:
                prod_term*=e_u[t][ir]

                if prod_term==0:
                    break

            if prod_term!=0:
                s+=pi[t-1]*prod_term

        out=s/denom

        p0_cache[idx]=out

        return out

    # --------------------------------------------------------
    # compute tilde with numeric lambdas
    # --------------------------------------------------------
    def tilde_fixed(idx,lams):

        l16=lams.get("l16",0)
        l6=lams.get("l6",0)

        l17=lams.get("l17",0)
        l7=lams.get("l7",0)

        l18=lams.get("l18",0)
        l8=lams.get("l8",0)

        Lam6=[None]+[l16]+[l6]*(K-1)
        Lam7=[None]+[l17]+[l7]*(K-1)
        Lam8=[None]+[l18]+[l8]*(K-1)

        bar4_cache={}
        bar5_cache={}
        bar6_cache={}

        def barq4(idx4):

            if idx4 in bar4_cache:
                return bar4_cache[idx4]

            i1,i2,i3,i4=idx4

            s=sp.Integer(0)

            for y in range(1,K+1):
                s+=norm_u[y]*Lam6[y]*p0_bar((i1,i2,y))*p0_bar((y,i3,i4))

            bar4_cache[idx4]=s

            return s

        def barq5(idx5):

            if idx5 in bar5_cache:
                return bar5_cache[idx5]

            i1,i2,i3,i4,i5=idx5

            s=sp.Integer(0)

            for x in range(1,K+1):
                s+=norm_u[x]*Lam7[x]*barq4((i1,i2,i3,x))*p0_bar((x,i4,i5))

            bar5_cache[idx5]=s

            return s

        def barq6(idx6):

            if idx6 in bar6_cache:
                return bar6_cache[idx6]

            i1,i2,i3,i4,i5,i6=idx6

            s=sp.Integer(0)

            for x in range(1,K+1):
                s+=norm_u[x]*Lam8[x]*barq5((i1,i2,i3,i4,x))*p0_bar((x,i5,i6))

            bar6_cache[idx6]=s

            return s

        den=p0_bar(idx)

        if den==0:
            return sp.nan

        if mode=="quartet":
            return barq4(idx)/den

        if mode=="5":
            return barq5(idx)/den

        if mode=="6":
            return barq6(idx)/den

    # --------------------------------------------------------
    # random lambda tests
    # --------------------------------------------------------
    equal=True

    for trial in range(NUM_RANDOM_TESTS):

        lam_test={

        "l16":random.randint(1,5),
        "l6":random.randint(1,5),

        "l17":random.randint(1,5),
        "l7":random.randint(1,5),

        "l18":random.randint(1,5),
        "l8":random.randint(1,5)
        }

        d = tilde_fixed(idx1,lam_test) - tilde_fixed(idx2,lam_test)

        d = simp_pi(d,piK_elim,PI_SUM)

        if d!=0:

            print("\nNOT EQUAL")
            print("(difference detected at trial",trial+1,")")

            print("\nLambda test values:",lam_test)

            print("\nDifference:")
            print(d)

            equal=False
            break

    if equal:

        print("\nLIKELY EQUAL")
        print(f"(no difference detected in {NUM_RANDOM_TESTS} random tests)")
        print("Increase NUM_RANDOM_TESTS for higher confidence.")

# ============================================================
if __name__ == "__main__":
    main()
# Out:
# Enter kappa (number of states), e.g. 8: 4
# Choose object (quartet / 5 / 6): 5
# Enter index #1: 22333
# Enter index #2: 33444
#
# NOT EQUAL
# (difference detected at trial 2 )
#
# Lambda test values: {'l16': 5, 'l6': 2, 'l17': 4, 'l7': 5, 'l18': 2, 'l8': 2}
#
# Difference:
# (-15*pi1**3 - 45*pi1**2*pi2 - 30*pi1**2*pi3 + 15*pi1**2 - 45*pi1*pi2**2 - 60*pi1*pi2*pi3 + 30*pi1*pi2 - 15*pi1*pi3**2 - 15*pi2**3 - 30*pi2**2*pi3 + 15*pi2**2 - 15*pi2*pi3**2 - 15*pi3**2)/(pi1*pi3 + pi2*pi3 + pi3**2 - pi3)
